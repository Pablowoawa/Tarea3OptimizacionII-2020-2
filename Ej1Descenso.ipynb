# %%
#Gradiente conjugado


import sympy as sym
import numpy as np
# código para tres dimensiones
n = 2
iterMax = 100
x = np.zeros((n, iterMax + 1))
# punto inicial
x[0][0] = -2
x[1][0] = -3

alfa = np.zeros(iterMax + 1)

d = np.zeros((n, iterMax + 1))
i = 0
x1 = sym.Symbol('x1')
x2 = sym.Symbol('x2')
# función
f1 = 2*(x1+1)**2 + 8*(x2+3)**2 +5*x1 + x2
# derivada parciales
dfx1 = sym.diff(f1, x1)
dfx2 = sym.diff(f1, x2)
alf = sym.Symbol('alf')
epsilon = 0.0001
while True:
    # Evaluar f(x_i)
    sol = f1.subs([(x1, x[0][i]), (x2, x[1][i])])
    # Gradiente
    d[0][i] = -1 * dfx1.subs([(x1, x[0][i]), (x2, x[1][i])])
    d[1][i] = -1 * dfx2.subs([(x1, x[0][i]), (x2, x[1][i])])

    # reemplazar en f(x_i + alfa * d_i)
    f2 = f1.subs([(x1, x[0][i] + alf * d[0][i]), (x2, x[1][i] + alf * d[1][i])])

    # resolver f(x_i + alfa * d_i)
    sol1 = sym.solve(sym.diff(f2, alf))

    # imprimir
    print(i, [x[0][i], x[1][i]], sol, [d[0][i], d[1][i]], sol1[0])

    alfa[i] = sol1[0]

    # condiones para terminar
    if abs(x[0][i] - x[0][i - 1]) <= epsilon and abs(x[1][i] - x[1][i - 1]) <= epsilon:
        break
    # recalcular x_{i + 1}
    x[0][i + 1] = x[0][i] + alfa[i] * d[0][i]
    x[1][i + 1] = x[1][i] + alfa[i] * d[1][i]

    i = i + 1
# Out:
# 0 [-2.0, -3.0] -11.0000000000000 [-1.0, -1.0] 0.100000000000000
# 1 [-2.1, -3.1] -11.1000000000000 [-0.5999999999999996, 0.6000000000000014] 0.100000000000000
# 2 [-2.16, -3.04] -11.1360000000000 [-0.35999999999999943, -0.35999999999999943] 0.100000000000000
# 3 [-2.196, -3.076] -11.1489600000000 [-0.2159999999999993, 0.21600000000000108] 0.0999999999999994
# 4 [-2.2176, -3.0544000000000002] -11.1536256000000 [-0.12959999999999994, -0.12959999999999638] 0.100000000000001
# 5 [-2.23056, -3.06736] -11.1553052160000 [-0.07775999999999961, 0.07775999999999783] 0.100000000000002
# 6 [-2.2383360000000003, -3.059584] -11.1559098777600 [-0.0466559999999987, -0.0466559999999987] 0.100000000000000
# 7 [-2.2430016000000004, -3.0642496] -11.1561275559936 [-0.02799359999999851, 0.02799360000000206] 0.0999999999999930
# 8 [-2.24580096, -3.06145024] -11.1562059201577 [-0.01679616000000017, -0.016796159999998395] 0.100000000000008
# 9 [-2.247480576, -3.063129856] -11.1562341312568 [-0.010077695999999747, 0.0100776960000033] 0.0999999999999803
# 10 [-2.2484883455999998, -3.0621220864] -11.1562442872524 [-0.006046617600000914, -0.006046617599999138] 0.100000000000017
# 11 [-2.24909300736, -3.0627267481600002] -11.1562479434109 [-0.0036279705600001932, 0.003627970560003746] 0.0999999999999407
# 12 [-2.249455804416, -3.062363951104] -11.1562492596279 [-0.0021767823360008265, -0.0021767823360008265] 0.0999999999999924
# 13 [-2.2496734826496, -3.0625816293376] -11.1562497334660 [-0.001306069401600496, 0.001306069401600496] 0.100000000000001
# 14 [-2.2498040895897597, -3.06245102239744] -11.1562499040478 [-0.0007836416409610081, -0.0007836416409574554] 0.100000000000255
# 15 [-2.249882453753856, -3.062529386561536] -11.1562499654572 [-0.00047018498457518376, 0.0004701849845787365] 0.0999999999995753
